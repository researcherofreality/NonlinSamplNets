# %% [markdown]
# The assumption is that each sensory neuron is Poisson and depends on a variable $z \in R^K$, and the population firing $s = \{ s_1,...,s_N \} \sim P(s|z) = \prod_i P(s_i | z)$, where
#
# $$P(s_i | z) = \frac{ \lambda_i(z)^{s_i}e^{- \lambda_i(z)}}{s_i!}$$
#
# We want to sample from the posterior $P(z | s) \propto P(s|z) \propto e^{-U(z)} = e^{-\sum_i U_i(z)}$.

# %%
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt

# %%
np.random.seed(4)

# %%
N = 10 # number of sensory neurons
K = 3 # number of hidden signals

T=20000 # tot taime steps
dt=0.0005 # time discretiz

K=3 # dimension Z
N=100 # number of sensory neurons

r0 = 10 # base firing rate
A=np.random.randn(N,K) # affinity matrix

# %%
# consider a slowly oscillating signal
zo = np.random.rand(K)* np.array([np.cos(np.linspace(b,10 + b,T)) + 1 for b in np.random.rand(K)*np.pi]).T

# get Poisson samples according to r_0 + Az
s = np.random.poisson(r0 + zo@A.T, [T,N])

# %%
plt.plot(zo)
# Out:
# [<matplotlib.lines.Line2D at 0x7fce1869cbb0>,
#  <matplotlib.lines.Line2D at 0x7fce186414f0>,
#  <matplotlib.lines.Line2D at 0x7fce18641610>]

# %% [markdown]
# Almost naive Langevin:
# $d\mathbf{z}(t) = - \epsilon \nabla U(\mathbf{z})\, dt + \sqrt{2 \epsilon}\, d\mathbf{W}(t)$
#
#  We need
# $\nabla_z U(z) = \sum_i (\nabla_z \lambda_i(z)) \left(1-\frac{s_i}{\lambda_i(z)} \right) $
#
# In the case where $\lambda_i(z) = r_0 + \alpha_i \cdot z$, $\alpha_i \in R^K$,
#
# $\nabla_z U(z) = \sum_i \alpha_i \left(1-\frac{s_i}{r_0 + \alpha_i \cdot z} \right) $

# %%
def DU(z,s=np.ones(N),A=A):
    return A.T@(1 - s/(r0 + A@z))

# %%
eps=12
z = np.zeros([T,K])
z[0] = zo[0]
for t in range(1,T):
    z[t] = z[t-1] - dt*eps*DU(z[t-1],s[t-1]) + np.sqrt(2*dt*eps)*np.random.randn(K)

# %%
plt.plot(z)
# Out:
# [<matplotlib.lines.Line2D at 0x7fce2f054040>,
#  <matplotlib.lines.Line2D at 0x7fce2f0540a0>,
#  <matplotlib.lines.Line2D at 0x7fce2f0541c0>]

# %%
plt.plot(ndimage.gaussian_filter1d(z,200,axis=0))
plt.twiny()
plt.plot(zo,ls='--')
# Out:
# [<matplotlib.lines.Line2D at 0x7fce28ab3ca0>,
#  <matplotlib.lines.Line2D at 0x7fce28ab3ee0>,
#  <matplotlib.lines.Line2D at 0x7fce28ad60d0>]

# %%
# try to implement a n-th order truncation
def DUn(z,s=np.ones(N),A=A,n=10):
    # wanto to approximate s/(r0 + A@z)
    sr0az = s/r0*np.sum([(-A@z/r0)**k for k in range(n+1)],0)
    return A.T@(1 - sr0az)

# %%
eps=12
z = np.zeros([T,K])
z[0] = zo[0]
for t in range(1,T):
    z[t] = z[t-1] - dt*eps*DUn(z[t-1],s[t-1],n=2) + np.sqrt(2*dt*eps)*np.random.randn(K)

# %%
plt.plot(z)
# Out:
# [<matplotlib.lines.Line2D at 0x7fce286d3af0>,
#  <matplotlib.lines.Line2D at 0x7fce2f158640>,
#  <matplotlib.lines.Line2D at 0x7fce28f735b0>]

# %%
plt.plot(ndimage.gaussian_filter1d(z,200,axis=0))
plt.twiny()
plt.plot(zo,ls='--')
# Out:
# [<matplotlib.lines.Line2D at 0x7fce28a385e0>,
#  <matplotlib.lines.Line2D at 0x7fce28a38730>,
#  <matplotlib.lines.Line2D at 0x7fce28a38850>]

# %% [markdown]
# # SCN with multiplicative synapses

# %% [markdown]
# Network spikes $\sigma$
#
# Filtered spikes $\dot r = -\lambda r + \sigma$
#
# Readout $\hat z = D r$

# %% [markdown]
# Network dynamics
# $\frac{dv}{dt} = -\lambda v + \epsilon D^T A^T (1-\frac{s}{r_0 + A D r}) + \sqrt{2\epsilon} D^T dW(t) + \lambda D^TD r - D^TD\sigma$

# %%
# Simulation parameters
Time = 100 # total time
dt = 0.0001 # time step
Nt=int(Time/dt) # number of time steps

# Network parameters
N = 100 # neurons
# K = 3 # dimensionality of z (SET ABOVE)
np.random.seed(12) # for reproducibility
D=np.random.randn(K,N) # decoding matrix
D = D / np.sqrt(np.diag(D.T@D)) # normalize vectors
D = D/10 # reduce size

# thresholds
T = np.diag(D.T@D)/2

# %%
V = np.zeros([N,Nt+1])
s = np.zeros([N,Nt+1])
r = np.zeros([N,Nt+1])

# Set initial conditions
r[:,0] = np.array(np.linalg.pinv(D)@zo[0]) # pseudo-inverse
V[:,0] = 0.9*T

# %%
### network connections ###
# - fast
O_f = - D.T @ D
# - slow
O_s = lam * D.T @ D
# - nonlinear part (not biological plausible atm)
def O_nl(r,s):
    return epsilon * D.T @ A.T *(1 - s) B @ np.kron(D,D)
