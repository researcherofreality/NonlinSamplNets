# %% [markdown]
# The assumption is that each sensory neuron is Poisson and depends on a variable $z \in R^K$, and the population firing $s = \{ s_1,...,s_N \} \sim P(s|z) = \prod_i P(s_i | z)$, where
#
# $$P(s_i | z) = \frac{ \lambda_i(z)^{s_i}e^{- \lambda_i(z)}}{s_i!}$$
#
# We want to sample from the posterior $P(z | s) \propto P(s|z) \propto e^{-U(z)} = e^{-\sum_i U_i(z)}$.

# %%
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt

# %%
# Simulation parameters
Time = T = 100 # total time
dt = 0.0001 # time step
nT = Nt = int(Time/dt) # number of time steps

# %%
np.random.seed(4)
# signal & (input) neuron dimension
K=3 # dimension Z
N=100 # number of sensory neurons

r0 = 10 # base firing rate
A=np.random.randn(N,K) # affinity matrix

# consider a slowly oscillating signal
zo = np.random.rand(K)* np.array([np.cos(np.linspace(b,10 + b,nT)) + 1 for b in np.random.rand(K)*np.pi]).T

# get Poisson samples according to r_0 + Az
s = np.random.poisson(r0 + zo@A.T, [nT,N])

# %%
plt.plot(zo[::100])
# Out:
# [<matplotlib.lines.Line2D at 0x7fce2e727ac0>,
#  <matplotlib.lines.Line2D at 0x7fce2e727b20>,
#  <matplotlib.lines.Line2D at 0x7fce2e727c40>]

# %% [markdown]
# Almost naive Langevin:
# $d\mathbf{z}(t) = - \epsilon \nabla U(\mathbf{z})\, dt + \sqrt{2 \epsilon}\, d\mathbf{W}(t)$
#
#  We need
# $\nabla_z U(z) = \sum_i (\nabla_z \lambda_i(z)) \left(1-\frac{s_i}{\lambda_i(z)} \right) $
#
# In the case where $\lambda_i(z) = r_0 + \alpha_i \cdot z$, $\alpha_i \in R^K$,
#
# $\nabla_z U(z) = \sum_i \alpha_i \left(1-\frac{s_i}{r_0 + \alpha_i \cdot z} \right) $

# %%
def DU(z,s=np.ones(N),A=A):
    return A.T@(1 - s/(r0 + A@z))

# %%
eps=12
z = np.zeros([nT,K])
z[0] = zo[0]
for t in range(1,nT):
    z[t] = z[t-1] - dt*eps*DU(z[t-1],s[t-1]) + np.sqrt(2*dt*eps)*np.random.randn(K)

# %%
plt.plot(z[::100])
# Out:
# [<matplotlib.lines.Line2D at 0x7fce2e69c8b0>,
#  <matplotlib.lines.Line2D at 0x7fce2e69c910>,
#  <matplotlib.lines.Line2D at 0x7fce2e69ca30>]

# %%
plt.plot(ndimage.gaussian_filter1d(z[::100],200,axis=0))
plt.twiny()
plt.plot(zo,ls='--')
# Out:
# [<matplotlib.lines.Line2D at 0x7fce2e648f10>,
#  <matplotlib.lines.Line2D at 0x7fce2e5d60a0>,
#  <matplotlib.lines.Line2D at 0x7fce2e5d61c0>]

# %%
# try to implement a n-th order truncation
def DUn(z,s=np.ones(N),A=A,n=10):
    # wanto to approximate s/(r0 + A@z)
    sr0az = s/r0*np.sum([(-A@z/r0)**k for k in range(n+1)],0)
    return A.T@(1 - sr0az)

# %% [markdown]
# ### second order approx

# %%
eps=12
z = np.zeros([nT,K])
z[0] = zo[0]
for t in range(1,nT):
    z[t] = z[t-1] - dt*eps*DUn(z[t-1],s[t-1],n=2) + np.sqrt(2*dt*eps)*np.random.randn(K)

# %%
plt.plot(z)
# Out:
# [<matplotlib.lines.Line2D at 0x7fce2eafa0d0>,
#  <matplotlib.lines.Line2D at 0x7fce2eafa130>,
#  <matplotlib.lines.Line2D at 0x7fce2eafa250>]

# %%
plt.plot(ndimage.gaussian_filter1d(z[::100],200,axis=0))
plt.twiny()
plt.plot(zo,ls='--')
# Out:
# [<matplotlib.lines.Line2D at 0x7fce2ea24460>,
#  <matplotlib.lines.Line2D at 0x7fce2ea245b0>,
#  <matplotlib.lines.Line2D at 0x7fce2ea246d0>]

# %% [markdown]
# ### third order

# %%
eps=12
z = np.zeros([nT,K])
z[0] = zo[0]
for t in range(1,nT):
    z[t] = z[t-1] - dt*eps*DUn(z[t-1],s[t-1],n=3) + np.sqrt(2*dt*eps)*np.random.randn(K)

# %%
plt.plot(ndimage.gaussian_filter1d(z[::100],200,axis=0))
plt.twiny()
plt.plot(zo,ls='--')
# Out:
# [<matplotlib.lines.Line2D at 0x7fce2e9577f0>,
#  <matplotlib.lines.Line2D at 0x7fce2e957940>,
#  <matplotlib.lines.Line2D at 0x7fce2e957a60>]

# %% [markdown]
# # SCN with nonlinear computations

# %% [markdown]
# Network spikes $\sigma$
#
# Filtered spikes $\dot r = -\lambda r + \sigma$
#
# Readout $\hat z = D r$

# %% [markdown]
# Network dynamics
# $\frac{dv}{dt} = -\lambda v + \epsilon D^T A^T (1-\frac{s}{r_0 + A D r}) + \sqrt{2\epsilon} D^T dW(t) + \lambda D^TD r - D^TD\sigma$

# %%
# Network parameters
Nn = 200 # neurons
# K = 3 # dimensionality of z (SET ABOVE)
np.random.seed(12) # for reproducibility
D=np.random.randn(K,Nn) # decoding matrix
D = D / np.sqrt(np.diag(D.T@D)) # normalize vectors
D = D/10 # reduce size

# thresholds
T = np.diag(D.T@D)/2

# %%
V = np.zeros([Nn,Nt+1])
sigma = np.zeros([Nn,Nt+1])
r = np.zeros([Nn,Nt+1])

# Set initial conditions
r[:,0] = np.array(np.linalg.pinv(D)@zo[0]) # pseudo-inverse
V[:,0] = 0.9*T

# %%
### network connections ###
lam=10
# - fast
O_f = - D.T @ D
# - slow
O_s = lam * D.T @ D
# - nonlinear part (not biological plausible atm)
epsilon=12
def O_nl(r,s): # need the 
    return  epsilon * D.T @ A.T @(1 - s / (r0 + A@D@r))

# %%
len(s[t])
# Out:
# 100

# %%
len(A@D@r[:,0])
# Out:
# 100

# %%
O_nl(r[:,t],s[t]).shape
# Out:
# (200,)

# %%
for t in range(Nt):
    V[:,t+1] = V[:,t] + dt*(-lam*V[:,t] + O_f@sigma[:,t] + O_s @ r[:,t] - O_nl(r[:,t],s[t]) + np.sqrt(epsilon*2)*D.T@np.random.randn(K))
    
    # check if there are neurons whose voltage is above threshold
    above = np.where(V[:,t+1] > T)[0]
    
    # introduce a control to let only one neuron fire
    if len(above):
        sigma[np.argmax(V[:,t+1]),t+1] = 1/dt
    
    # update rate
    r[:,t+1] = r[:,t] + dt*(sigma[:,t+1] - lam*r[:,t])

# %%
plt.plot((D@r).T[1000:][::100],alpha=0.3,label='output')
plt.twiny()
plt.plot(zo,ls='--',label='true')
# plt.legend()
# Out:
# [<matplotlib.lines.Line2D at 0x7fce288e25b0>,
#  <matplotlib.lines.Line2D at 0x7fce288e2940>,
#  <matplotlib.lines.Line2D at 0x7fce288e2b80>]
